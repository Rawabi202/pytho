# %%
#import pandas in jupyter noteBook environment:
import pandas

# %%
dataset = pandas.read_excel("diabetic.xlsx")

# %%
import pandas as pd

# %%
dataset = pd.read_excel("diabetic.xlsx")

# %%
dataset
# Out:
#    زيارات المراجعين لعيادات السكرى بمستشفيات وزارة الصحة حسب الجنس والجنسية والمنطقة عام 1439هـ (2018م)  \
# 0    Visits to  Diabetic  Clinics, MOH Hospitals b...
# 1                                           جدول 4-14
# 2                                            المنطقة
# 3                                                 NaN
# 4                                              الرياض
# 5                                         مكة المكرمة
# 6                                                 جدة
# 7                                             الطائف
# 8                                    المدينة المنورة
# 9                                             القصيم
# 10                                           الشرقية
# 11                                           الأحساء
# 12                                        حفر الباطن
# 13                                              عسير
# 14                                               بيشة
# 15                                              تبوك
# ...
